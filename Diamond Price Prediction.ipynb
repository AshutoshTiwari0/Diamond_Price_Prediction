# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Dell\\Downloads\\diamonds.csv\\diamonds.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# Some data info from kaggle
#
# price price in US dollars (\$326--\$18,823)
#
# carat weight of the diamond (0.2--5.01)
#
# cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color diamond colour, from J (worst) to D (best)
#
# clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x length in mm (0--10.74)
#
# y width in mm (0--58.9)
#
# z depth in mm (0--31.8)
#
# depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# table width of top of diamond relative to widest point (43--95)

# %%
#dropping unnamed column
df=df.drop(labels='Unnamed: 0',axis=1)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
numerical_features=['carat','depth','table','x','y','z']

# %% [markdown]
# price is our target variable

# %%
#lets change the name of x y z
df=df.rename(columns={'x':'Length',
                  'y':'Width',
                  'z':'Height'})

# %%
cut_group=df.groupby('cut')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price  Length  Width  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       0.21    Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       0.23       Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       0.29    Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       0.31       Good     J     SI2   63.3   58.0    335    4.34   4.35
# ...      ...        ...   ...     ...    ...    ...    ...     ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757    5.75   5.76
# 53936   0.72       Good     D     SI1   63.1   55.0   2757    5.69   5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757    5.66   5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757    6.15   6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757    5.83   5.87
#
#        Height
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# ...

# %% [markdown]
# changing cut to numerical value

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
sns.countplot(x=df['cut'])
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.countplot(x=df['color'])
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %% [markdown]
# seeing relation between color and price

# %%
sns.barplot(x=df['color'],y=df['price'])
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %% [markdown]
# The above plot tells us that colors i j and h have the highest prices and colors e and d have lowest price.

# %% [markdown]
# lets see now price and clarity

# %%
sns.barplot(x=df['clarity'],y=df['price'])
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %% [markdown]
# seeing relationship bewtween price and carat

# %%
sns.lineplot(x=df['carat'],y=df['price'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x=df['carat'],y=df['price'])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x=df['depth'],y=df['price'])
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %%
sns.scatterplot(x=df['table'],y=df['price'])
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %%
#lets see how carat depth and table are related with each other

# %%
sns.lineplot(x=df['carat'],y=df['table'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='carat', ylabel='table'>

# %% [markdown]
# How length, width, height affect price

# %%
dimensions=['Length']

# %%
for i in dimensions:
    sns.lineplot(x=df[i],y=df['price'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# There are very huge variations

# %%
sns.lineplot(x=df['Width'],y=df['price'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Width', ylabel='price'>

# %%
sns.lineplot(x=df['Height'],y=df['price'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Height', ylabel='price'>

# %% [markdown]
# To achieve a good price for our diamond we should have a length between 4-9

# %% [markdown]
# Analyzing it better with the help of co relation

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# Length     float64
# Width      float64
# Height     float64
# dtype: object

# %%
numerical_features
# Out:
# ['carat', 'depth', 'table', 'x', 'y', 'z']

# %%
categorical_features=['cut','color','clarity']

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# Length     0
# Width      0
# Height     0
# dtype: int64

# %%
df[categorical_features].value_counts()
# Out:
# cut    color  clarity
# Ideal  E      VS2        1136
#        G      VS1         953
#        D      VS2         920
#        G      VS2         910
#        F      VS2         879
#                          ...
# Fair   H      VVS1          1
#        I      VVS1          1
#        J      VVS2          1
# Good   J      VVS1          1
# Fair   J      VVS1          1
# Name: count, Length: 276, dtype: int64

# %% [markdown]
# Converting categorical data to numerical data via a map

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price  Length  Width  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       0.21    Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       0.23       Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       0.29    Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       0.31       Good     J     SI2   63.3   58.0    335    4.34   4.35
# ...      ...        ...   ...     ...    ...    ...    ...     ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757    5.75   5.76
# 53936   0.72       Good     D     SI1   63.1   55.0   2757    5.69   5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757    5.66   5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757    6.15   6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757    5.83   5.87
#
#        Height
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# ...

# %% [markdown]
# There are three categorical data -> cut color clarity
# <br/>
# cut-> Ideal Premium Good Very Good Fair
# <br/>
# color-> E I J H F G D
# <br/>
# clarity-> S12 S11 VS1 VS2 WS2 WS1 I1 IF

# %% [markdown]
# There will be huge dataset if i will use get dummies. So lets try to implement mapping.

# %%
df['cut'] = df['cut'].replace({'Ideal':0,'Fair':1,'Good':2,'Very Good':3, 'Premium':4})

# %%
df
# Out:
#        carat  cut color clarity  depth  table  price  Length  Width  Height
# 0       0.23    0     E     SI2   61.5   55.0    326    3.95   3.98    2.43
# 1       0.21    4     E     SI1   59.8   61.0    326    3.89   3.84    2.31
# 2       0.23    2     E     VS1   56.9   65.0    327    4.05   4.07    2.31
# 3       0.29    4     I     VS2   62.4   58.0    334    4.20   4.23    2.63
# 4       0.31    2     J     SI2   63.3   58.0    335    4.34   4.35    2.75
# ...      ...  ...   ...     ...    ...    ...    ...     ...    ...     ...
# 53935   0.72    0     D     SI1   60.8   57.0   2757    5.75   5.76    3.50
# 53936   0.72    2     D     SI1   63.1   55.0   2757    5.69   5.75    3.61
# 53937   0.70    3     D     SI1   62.8   60.0   2757    5.66   5.68    3.56
# 53938   0.86    4     H     SI2   61.0   58.0   2757    6.15   6.12    3.74
# 53939   0.75    0     D     SI2   62.2   55.0   2757    5.83   5.87    3.64
#
# [53940 rows x 10 columns]

# %%
df['color'] = df['color'].replace({'E':0,'I':1,'J':2,'H':3, 'F':4, 'G':5, 'D':6})

# %%
df
# Out:
#        carat  cut  color clarity  depth  table  price  Length  Width  Height
# 0       0.23    0      0     SI2   61.5   55.0    326    3.95   3.98    2.43
# 1       0.21    4      0     SI1   59.8   61.0    326    3.89   3.84    2.31
# 2       0.23    2      0     VS1   56.9   65.0    327    4.05   4.07    2.31
# 3       0.29    4      1     VS2   62.4   58.0    334    4.20   4.23    2.63
# 4       0.31    2      2     SI2   63.3   58.0    335    4.34   4.35    2.75
# ...      ...  ...    ...     ...    ...    ...    ...     ...    ...     ...
# 53935   0.72    0      6     SI1   60.8   57.0   2757    5.75   5.76    3.50
# 53936   0.72    2      6     SI1   63.1   55.0   2757    5.69   5.75    3.61
# 53937   0.70    3      6     SI1   62.8   60.0   2757    5.66   5.68    3.56
# 53938   0.86    4      3     SI2   61.0   58.0   2757    6.15   6.12    3.74
# 53939   0.75    0      6     SI2   62.2   55.0   2757    5.83   5.87    3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)

# %%
df['clarity']=df['clarity'].replace({'L1':0,
                                    'SI2':1,
                                    'SI1':2,
                                    'VS2':3,
                                    'VS1':4,
                                    'VVS2':5,
                                    'VVS1':6,
                                    'I1':7})

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price  Length  Width  Height
# 0       0.23    0      0        1   61.5   55.0    326    3.95   3.98    2.43
# 1       0.21    4      0        2   59.8   61.0    326    3.89   3.84    2.31
# 2       0.23    2      0        4   56.9   65.0    327    4.05   4.07    2.31
# 3       0.29    4      1        3   62.4   58.0    334    4.20   4.23    2.63
# 4       0.31    2      2        1   63.3   58.0    335    4.34   4.35    2.75
# ...      ...  ...    ...      ...    ...    ...    ...     ...    ...     ...
# 53935   0.72    0      6        2   60.8   57.0   2757    5.75   5.76    3.50
# 53936   0.72    2      6        2   63.1   55.0   2757    5.69   5.75    3.61
# 53937   0.70    3      6        2   62.8   60.0   2757    5.66   5.68    3.56
# 53938   0.86    4      3        1   61.0   58.0   2757    6.15   6.12    3.74
# 53939   0.75    0      6        1   62.2   55.0   2757    5.83   5.87    3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# checking outliers

# %%
sns.boxplot(df['carat'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['depth'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['table'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Length'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Width'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: >

# %% [markdown]
# Removing them is not looking good bcoz in above plots carat has outliers but a big value of carat might also mean higher price.

# %% [markdown]
# lets do fit transfrom

# %%
Y=df['price']

# %%
Y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price  Length  Width  Height
# 0       0.23    0      0        1   61.5   55.0    326    3.95   3.98    2.43
# 1       0.21    4      0        2   59.8   61.0    326    3.89   3.84    2.31
# 2       0.23    2      0        4   56.9   65.0    327    4.05   4.07    2.31
# 3       0.29    4      1        3   62.4   58.0    334    4.20   4.23    2.63
# 4       0.31    2      2        1   63.3   58.0    335    4.34   4.35    2.75
# ...      ...  ...    ...      ...    ...    ...    ...     ...    ...     ...
# 53935   0.72    0      6        2   60.8   57.0   2757    5.75   5.76    3.50
# 53936   0.72    2      6        2   63.1   55.0   2757    5.69   5.75    3.61
# 53937   0.70    3      6        2   62.8   60.0   2757    5.66   5.68    3.56
# 53938   0.86    4      3        1   61.0   58.0   2757    6.15   6.12    3.74
# 53939   0.75    0      6        1   62.2   55.0   2757    5.83   5.87    3.64
#
# [53940 rows x 10 columns]

# %%
Y=df.iloc[:,6]

# %%
Y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
X=df.loc[:,df.columns!= 'price']

# %%
X
# Out:
#        carat  cut  color  clarity  depth  table  Length  Width  Height
# 0       0.23    0      0        1   61.5   55.0    3.95   3.98    2.43
# 1       0.21    4      0        2   59.8   61.0    3.89   3.84    2.31
# 2       0.23    2      0        4   56.9   65.0    4.05   4.07    2.31
# 3       0.29    4      1        3   62.4   58.0    4.20   4.23    2.63
# 4       0.31    2      2        1   63.3   58.0    4.34   4.35    2.75
# ...      ...  ...    ...      ...    ...    ...     ...    ...     ...
# 53935   0.72    0      6        2   60.8   57.0    5.75   5.76    3.50
# 53936   0.72    2      6        2   63.1   55.0    5.69   5.75    3.61
# 53937   0.70    3      6        2   62.8   60.0    5.66   5.68    3.56
# 53938   0.86    4      3        1   61.0   58.0    6.15   6.12    3.74
# 53939   0.75    0      6        1   62.2   55.0    5.83   5.87    3.64
#
# [53940 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.19816781, -1.12612218, -1.54839233, ..., -1.58783745,
#         -1.53619556, -1.57112919],
#        [-1.24036129,  1.23668435, -1.54839233, ..., -1.64132529,
#         -1.65877419, -1.74117497],
#        [-1.19816781,  0.05528109, -1.54839233, ..., -1.49869105,
#         -1.45739502, -1.74117497],
#        ...,
#        [-0.20662095,  0.64598272,  1.37824171, ..., -0.06343409,
#         -0.04774083,  0.03013526],
#        [ 0.13092691,  1.23668435, -0.08507531, ...,  0.37338325,
#          0.33750627,  0.28520393],
#        [-0.10113725, -1.12612218,  1.37824171, ...,  0.08811478,
#          0.11861587,  0.14349912]])

# %%
Y=df['price']

# %%
Y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# I think now we can go for model building

# %% [markdown]
# It is a regression problem. So lets use linear, ridge, lasso, polynomial regression

# %%
X
# Out:
#        carat  cut  color  clarity  depth  table  Length  Width  Height
# 0       0.23    0      0        1   61.5   55.0    3.95   3.98    2.43
# 1       0.21    4      0        2   59.8   61.0    3.89   3.84    2.31
# 2       0.23    2      0        4   56.9   65.0    4.05   4.07    2.31
# 3       0.29    4      1        3   62.4   58.0    4.20   4.23    2.63
# 4       0.31    2      2        1   63.3   58.0    4.34   4.35    2.75
# ...      ...  ...    ...      ...    ...    ...     ...    ...     ...
# 53935   0.72    0      6        2   60.8   57.0    5.75   5.76    3.50
# 53936   0.72    2      6        2   63.1   55.0    5.69   5.75    3.61
# 53937   0.70    3      6        2   62.8   60.0    5.66   5.68    3.56
# 53938   0.86    4      3        1   61.0   58.0    6.15   6.12    3.74
# 53939   0.75    0      6        1   62.2   55.0    5.83   5.87    3.64
#
# [53940 rows x 9 columns]

# %%
Y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.7,random_state=1234)

# %%
X_train
# Out:
#        carat  cut  color  clarity  depth  table  Length  Width  Height
# 45826   0.65    4      5        2   59.9   59.0    5.69   5.62    3.39
# 33365   0.41    4      5        3   61.6   58.0    4.73   4.78    2.93
# 18120   1.13    1      4        4   64.5   55.0    6.62   6.56    4.25
# 46200   0.68    4      5        2   61.9   60.0    5.66   5.62    3.49
# 20441   1.51    1      5        3   56.0   65.0    7.68   7.57    4.27
# ...      ...  ...    ...      ...    ...    ...     ...    ...     ...
# 32399   0.38    0      1        6   61.6   56.0    4.68   4.71    2.89
# 17048   0.30    0      4        4   62.1   55.0    4.31   4.35    2.69
# 23924   2.01    0      2        2   62.1   56.0    8.08   8.03    5.00
# 34086   0.36    4      0        4   60.4   58.0    4.64   4.67    2.81
# 27439   2.04    4      4        1   60.2   58.0    8.17   8.24    4.94
#
# [37758 rows x 9 columns]

# %%
X_test
# Out:
#        carat  cut  color  clarity  depth  table  Length  Width  Height
# 18197   1.57    0      1        1   62.8   57.0    7.39   7.36    4.63
# 34622   0.31    4      0        3   60.6   59.0    4.39   4.36    2.65
# 42495   0.51    3      4        2   61.7   55.0    5.14   5.16    3.18
# 40139   0.70    1      5        7   64.6   59.0    5.64   5.48    3.60
# 3872    0.90    3      3        1   62.3   61.0    6.15   6.17    3.84
# ...      ...  ...    ...      ...    ...    ...     ...    ...     ...
# 37362   0.40    4      5        5   61.1   58.0    4.74   4.76    2.90
# 11247   1.28    0      2        2   61.2   57.0    7.02   6.96    4.28
# 42165   0.52    4      6        2   62.0   60.0    5.18   5.11    3.19
# 5869    0.92    1      3        4   56.0   60.0    6.53   6.51    3.65
# 17534   1.01    0      4        4   61.7   59.0    6.44   6.42    3.97
#
# [16182 rows x 9 columns]

# %%
Y_train
# Out:
# 45826     1712
# 33365      827
# 18120     7335
# 46200     1749
# 20441     8794
#          ...
# 32399      791
# 17048      612
# 23924    12048
# 34086      852
# 27439    18066
# Name: price, Length: 37758, dtype: int64

# %%
Y_test
# Out:
# 18197    7385
# 34622     872
# 42495    1320
# 40139    1115
# 3872     3481
#          ...
# 37362     982
# 11247    4967
# 42165    1284
# 5869     3924
# 17534    7056
# Name: price, Length: 16182, dtype: int64

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict=lr.predict(X_test)

# %%
Y_predict
# Out:
# array([9421.72662108,  -71.95136888, 1455.66509124, ..., 1249.78214271,
#        5431.42186827, 5656.35725144])

# %%
from sklearn.metrics import mean_squared_error

# %%
import numpy as np

# %%
rmse=np.sqrt(mean_squared_error(Y_test,Y_predict))

# %%
rmse
# Out:
# 1438.940135723088

# %%
from sklearn.metrics import r2_score

r2=r2_score(Y_test,Y_predict)

# %%
r2
# Out:
# 0.8700982384932165

# %%
lr.score(X_test,Y_test)
# Out:
# 0.8700982384932165

# %% [markdown]
# Adjusted r2

# %%
intercept=lr.intercept_

# %%
intercept
# Out:
# 15039.787562631262

# %%
coefficient=lr.coef_

# %%
coefficient
# Out:
# array([ 1.04342788e+04, -5.60921973e-01,  8.49258927e+01,  2.85131402e+02,
#        -1.70737000e+02, -7.68033877e+01, -1.04844832e+03,  5.11925614e+01,
#         2.18998912e+01])

# %%
from sklearn.linear_model import Lasso, Ridge,ElasticNet

# %%
ls=Lasso()

# %%
ls.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
Y_predict_ls=ls.predict(X_test)

# %%
Y_predict_ls
# Out:
# array([9412.97632174,  -82.4299981 , 1459.21789948, ..., 1257.97960601,
#        5446.37234054, 5668.72179098])

# %%
rmse_ls=np.sqrt(mean_squared_error(Y_test,Y_predict_ls))

# %%
rmse_ls
# Out:
# 0.0

# %%
from sklearn.metrics import r2_score

r2_ls=r2_score(Y_test,Y_predict_ls)

# %%
r2_ls
# Out:
# 1.0

# %%
ridge=Ridge()

# %%
ridge.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
Y_predict_rigde=ridge.predict(X_test)

# %%
rmse_ridge=np.sqrt(mean_squared_error(Y_test,Y_predict_rigde))

# %%
rmse_ridge
# Out:
# 12.386109833616047

# %%
r2_ridge=r2_score(Y_test,Y_predict_rigde)

# %%
r2_ridge
# Out:
# 0.9999890546694286

# %%
en=ElasticNet()

# %%
en.fit(X_train,Y_train)
# Out:
# ElasticNet()

# %%
Y_predict_en=en.predict(X_test)

# %%
rmse_en=np.sqrt(mean_squared_error(Y_test,Y_predict_en))

# %%
rmse_en
# Out:
# 1137.923585231604

# %%
r2_en=r2_score(Y_test,Y_predict_en)

# %%
r2_en
# Out:
# 0.907618453759756

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data - replace these with your actual values
models = ['Linear', 'ElasticNet', 'Ridge', 'Lasso']
r2_scores = [0.87, 0.90, 0.99, 1.00]  # Replace with your R² scores
rmse_scores = [1438.94, 1137.92, 12.38,0.0]    # Replace with your RMSE scores

# Creating the bar plot for R² scores
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = np.arange(len(models))

bar1 = ax1.bar(index, r2_scores, bar_width, label='R² Score', color='b')

# Creating the bar plot for RMSE scores
ax2 = ax1.twinx()
bar2 = ax2.bar(index + bar_width, rmse_scores, bar_width, label='RMSE', color='g')

# Adding labels, title, and custom x-axis tick labels
ax1.set_xlabel('Model')
ax1.set_ylabel('R² Score', color='b')
ax2.set_ylabel('RMSE', color='g')
ax1.set_title('Comparison of Linear Regression Models')
ax1.set_xticks(index + bar_width / 2)
ax1.set_xticklabels(models)

# Adding legend
bars = bar1 + bar2
labs = [b.get_label() for b in bars]
ax1.legend(bars, labs, loc='upper right')

# Displaying the plot
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_340\686904493.py:32: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   ax1.legend(bars, labs, loc='upper right')
